# %% [markdown]
# <div style="border-radius:10px; border:#DEB887 solid; padding: 15px; background-color: #FFFAF0; font-size:100%; text-align:left">
#
# <h3 align="center"><font color='#DEB887'>Car Sales Exploratory Data Analysis</font></h3>
# <div style="font-family:Georgia;background-color:'black'; font-color:'black',padding:30px; font-size:17px">

# %% [markdown]
# ![Jidd-Motors-Chicago-Luxury-Auto-Dealer-Mercedes-Showroom-1005.jpg](attachment:Jidd-Motors-Chicago-Luxury-Auto-Dealer-Mercedes-Showroom-1005.jpg)

# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:5px;
#            background-color:pink;
#            font-size:200%;
#            font-family:Serif;
#            letter-spacing:0.5px">
#
# <p style="padding: 10px;
#           color:black;
#           font-size:120%;
#           text-align:center;">
# Goal of  Project:Analyse and Interpretation of trends in resale cars
# </p>
# </div>

# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:5px;
#            background-color:pink;
#            font-size:200%;
#            font-family:Serif;
#            letter-spacing:0.5px">
#
# <p style="padding: 10px;
#           color:black;
#           font-size:120%;
#           text-align:center;">
# Source of Data : Kaggle.com
# </p>
# </div>

# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:5px;
#            background-color:pink;
#            font-size:200%;
#            font-family:Serif;
#            letter-spacing:0.5px">
#
# <p style="padding: 10px;
#           color:black;
#           font-size:120%;
#           text-align:center;">
# Work Flow
# </p>
# </div>

# %% [markdown]
# - Step 1-- importing the required libraries...
# - step 2-- loading the data set
# - step 3-- Basic understanding of data
# - step 4-- Preprocessing

# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:5px;
#            background-color:pink;
#            font-size:200%;
#            font-family:Serif;
#            letter-spacing:0.5px">
#
# <p style="padding: 10px;
#           color:black;
#           font-size:120%;
#           text-align:center;">
# Step 1: Importing the Required Libraries
# </p>
# </div>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:5px;
#            background-color:pink;
#            font-size:200%;
#            font-family:Serif;
#            letter-spacing:0.5px">
#
# <p style="padding: 10px;
#           color:black;
#           font-size:120%;
#           text-align:center;">
# Step 2: Loading the Data Set
# </p>
# </div>

# %%
df=pd.read_csv("C:/Users/acer/Downloads/cars.csv")

# %% [markdown]
# ### Execution process during Reading the file
# **First go through C drive then Users then Acer then Downloads and then Cars.csv file in this sys**

# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:5px;
#            background-color:pink;
#            font-size:200%;
#            font-family:Serif;
#            letter-spacing:0.5px">
#
# <p style="padding: 10px;
#           color:black;
#           font-size:120%;
#           text-align:center;">
# Step 3: Basic understanding of Data
# </p>
# </div>

# %% [markdown]
# ## Preview of Data

# %%
df.head()
# Out:
#    Index         carName  year of bought fuelType  kilometerDriven  \
# 0      0  Datsun Redi Go            2018   Petrol            22664
# 1      1   Hyundai Verna            2019   Petrol            81902
# 2      2      KIA SELTOS            2020   Petrol             8241
# 3      3      KIA SELTOS            2020   Petrol            32799
# 4      4      KIA SELTOS            2019   Petrol            37357
#
#    Unnamed: 5  originalPrice       city   bodyType transmission  \
# 0         NaN         242999  Ghaziabad  Hatchback       Manual
# 1         NaN         981699    Gurgaon      Sedan       Manual
# 2         NaN        1895199  New Delhi        SUV    Automatic
# 3         NaN        1375499    Gurgaon        SUV       Manual
# 4         NaN        1666099  New Delhi        SUV    Automatic
#
#   registrationCity registrationState     make    model
# 0             Agra     Uttar Pradesh   DATSUN  REDI GO
# 1          Gurgaon           Haryana  HYUNDAI    VERNA
# ...

# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:5px;
#            background-color:pink;
#            font-size:200%;
#            font-family:Serif;
#            letter-spacing:0.5px">
#
# <p style="padding: 10px;
#           color:black;
#           font-size:120%;
#           text-align:center;">
# Step 4: Checking the Shape of the Data
# </p>
# </div>

# %%
df.shape
# Out:
# (592, 14)

# %% [markdown]
# **Observations**
# - The Dataset has 592 Rows and 14 Columns.

# %% [markdown]
# # Basic Information of the Data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 592 entries, 0 to 591
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Index              592 non-null    int64
#  1   carName            592 non-null    object
#  2   year of bought     592 non-null    int64
#  3   fuelType           592 non-null    object
#  4   kilometerDriven    592 non-null    int64
#  5   Unnamed: 5         0 non-null      float64
#  6   originalPrice      592 non-null    int64
#  7   city               592 non-null    object
#  8   bodyType           570 non-null    object
#  9   transmission       570 non-null    object
#  10  registrationCity   592 non-null    object
#  11  registrationState  592 non-null    object
#  12  make               592 non-null    object
#  13  model              592 non-null    object
# dtypes: float64(1), int64(4), object(9)
# memory usage: 64.9+ KB

# %% [markdown]
# **Observations**
# - From above output all the columns are in appropriate datatype.so, we do not require to change the datatype of any column.
# - We clearly see that there are 2 columns one is body type and second one is transmission, which contains some null values.
# - We clearly see that there is an unnecessary column named- Unnamed: 5 and we have to remove it before starting the analysis.

# %% [markdown]
# ### Drop Unnecessary Column in the Dataset

# %%
df.drop(columns='Unnamed: 5',inplace=True)

# %%
df.head(3)
# Out:
#    Index         carName  year of bought fuelType  kilometerDriven  \
# 0      0  Datsun Redi Go            2018   Petrol            22664
# 1      1   Hyundai Verna            2019   Petrol            81902
# 2      2      KIA SELTOS            2020   Petrol             8241
#
#    originalPrice       city   bodyType transmission registrationCity  \
# 0         242999  Ghaziabad  Hatchback       Manual             Agra
# 1         981699    Gurgaon      Sedan       Manual          Gurgaon
# 2        1895199  New Delhi        SUV    Automatic            Delhi
#
#   registrationState     make    model
# 0     Uttar Pradesh   DATSUN  REDI GO
# 1           Haryana  HYUNDAI    VERNA
# 2             Delhi      KIA   SELTOS

# %% [markdown]
# **Observations**
# - Unnamed: 5 has been deleted from the data set.
# - Inplace=True has to be used for the upgradation in the original dataset

# %%
df.set_index('Index',inplace=True)

# %%
df.head(3)
# Out:
#               carName  year of bought fuelType  kilometerDriven  \
# Index
# 0      Datsun Redi Go            2018   Petrol            22664
# 1       Hyundai Verna            2019   Petrol            81902
# 2          KIA SELTOS            2020   Petrol             8241
#
#        originalPrice       city   bodyType transmission registrationCity  \
# Index
# 0             242999  Ghaziabad  Hatchback       Manual             Agra
# 1             981699    Gurgaon      Sedan       Manual          Gurgaon
# 2            1895199  New Delhi        SUV    Automatic            Delhi
#
#       registrationState     make    model
# Index
# 0         Uttar Pradesh   DATSUN  REDI GO
# 1               Haryana  HYUNDAI    VERNA
# 2                 Delhi      KIA   SELTOS

# %% [markdown]
# ### Drop Some Irrelevant Columns in the Dataset

# %%
df.drop(columns=['carName'],inplace=True)

# %% [markdown]
# **Observations**
# - In my opinion,the values of the Car name column is similar to the values of the (Make and Model) column
# - so this is my first     concern for deleting the column, with the help of column deletion it helps to avoid data redundancy and enhance data             integrity.

# %%
df.head(3)
# Out:
#        year of bought fuelType  kilometerDriven  originalPrice       city  \
# Index
# 0                2018   Petrol            22664         242999  Ghaziabad
# 1                2019   Petrol            81902         981699    Gurgaon
# 2                2020   Petrol             8241        1895199  New Delhi
#
#         bodyType transmission registrationCity registrationState     make  \
# Index
# 0      Hatchback       Manual             Agra     Uttar Pradesh   DATSUN
# 1          Sedan       Manual          Gurgaon           Haryana  HYUNDAI
# 2            SUV    Automatic            Delhi             Delhi      KIA
#
#          model
# Index
# 0      REDI GO
# 1        VERNA
# 2       SELTOS

# %% [markdown]
# ### Rename columns in the dataset

# %%
df.rename(columns={'year of bought':'Year of bought','fuelType':'Fuel Type','kilometerDriven':'KM Driven',
                  'originalPrice':'Sales Price','city':'City','bodyType':'Body Type','transmission':'Transmission','registrationCity':'Registration City',
                  'registrationState':'State','make':'Company','model':'Model'},inplace=True)

# %% [markdown]
# # Data Dictionary

# %%
df.columns
# Out:
# Index(['Year of bought', 'Fuel Type', 'KM Driven', 'Sales Price', 'City',
#        'Body Type', 'Transmission', 'Registration City', 'State', 'Company',
#        'Model'],
#       dtype='object')

# %% [markdown]
# **Column Description**
# - Year of Bought- Car Purchased year in the Dataset
# - Fuel Type     - Type of Fuel in the car (Petrol/Diesel/CNG)
# - KM Driven     - Kilometer Driven by the Owner of the Car after Manufactured
# - Sales Price   - Sales price of the Car
# - City          - Store City
# - Body Type     - Car Structure in the dataset(Hatchback/SUV/MUV etc.)
# - Transmission  - (Manual/AMT) transmission of the car
# - Registration City         - Registration city of the car
# - State         - Registration state of the car
# - Company       - Company of the Car
# - Model         - Model of the car in the dataset

# %% [markdown]
# **Observations**
# - Assumptions- we are doing analysis on the car sales data,so we are assuming that the city as Store city of the car.

# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:5px;
#            background-color:pink;
#            font-size:200%;
#            font-family:Serif;
#            letter-spacing:0.5px">
#
# <p style="padding: 10px;
#           color:black;
#           font-size:120%;
#           text-align:center;">
# Step 5: Preprocessing Step
# </p>
# </div>

# %% [markdown]
# # Checking the Missing values according to the Numeric data types of the columns

# %%
Num=df.select_dtypes(include=['int','float'])
Num
# Out:
#        Year of bought  KM Driven  Sales Price
# Index
# 0                2018      22664       242999
# 1                2019      81902       981699
# 2                2020       8241      1895199
# 3                2020      32799      1375499
# 4                2019      37357      1666099
# ...               ...        ...          ...
# 587              2018      88168       891599
# 588              2017      51900       427099
# 589              2018      60264       425299
# 590              2020      16315      1755399
# 591              2020      24208       584499
#
# [592 rows x 3 columns]

# %%
Num.columns
# Out:
# Index(['Year of bought', 'KM Driven', 'Sales Price'], dtype='object')

# %%
for i in Num.columns:
    if Num[i].isnull().sum()>0:
        print(i,'       ',Num[i].isnull().sum()*100/Num.shape[0],'%')

# %% [markdown]
# **Observations**
# - I had run the code & there is no any output, it means no any null values in the numeric columns of the dataset

# %% [markdown]
# # Checking the Missing values according to the Categorical data types of the columns

# %%
Cat=df.select_dtypes(exclude=['int','float'])
Cat
# Out:
#       Fuel Type       City  Body Type Transmission Registration City  \
# Index
# 0        Petrol  Ghaziabad  Hatchback       Manual              Agra
# 1        Petrol    Gurgaon      Sedan       Manual           Gurgaon
# 2        Petrol  New Delhi        SUV    Automatic             Delhi
# 3        Petrol    Gurgaon        SUV       Manual            Rewari
# 4        Petrol  New Delhi        SUV    Automatic            Rohtak
# ...         ...        ...        ...          ...               ...
# 587      Diesel  New Delhi        SUV       Manual             Delhi
# 588      Petrol    Gurgaon  Hatchback       Manual           Gurgaon
# 589      Petrol      Noida  Hatchback       Manual         New Delhi
# 590      Petrol    Gurgaon        SUV    Automatic           Gurgaon
# 591      Petrol  New Delhi  Hatchback       Manual           Gurgaon
#
#                State  Company        Model
# Index
# 0      Uttar Pradesh   DATSUN      REDI GO
# ...

# %%
Cat.columns
# Out:
# Index(['Fuel Type', 'City', 'Body Type', 'Transmission', 'Registration City',
#        'State', 'Company', 'Model'],
#       dtype='object')

# %%
for i in Cat.columns:
    if Cat[i].isnull().sum()>0:
        print(i,'       ',Cat[i].isnull().sum()*100/Cat.shape[0],'%')
# Out:
# Body Type         3.7162162162162162 %
# Transmission         3.7162162162162162 %

# %% [markdown]
# **Observations**
# - We can clearly see that there are 2 columns who have contains some missing values near about 3.7%
# - First is Body type and second is Transmission.
# - We can either fill it or drop it as per the requirements in the data set.

# %% [markdown]
# ## How much % missing values are there in the whole data set column wise

# %%
df.isnull().sum().to_frame().rename(columns={0:"missing values count"}).T
# Out:
#                       Year of bought  Fuel Type  KM Driven  Sales Price  City  \
# missing values count               0          0          0            0     0
#
#                       Body Type  Transmission  Registration City  State  \
# missing values count         22            22                  0      0
#
#                       Company  Model
# missing values count        0      0

# %% [markdown]
# **Observations**
# - We can clearly see that there are 2 columns who have contains some missing values.
# - First is Body type and second is Transmission.
# - We can either fill it or drop it as per the requirements in the data set.

# %% [markdown]
# # Checking the duplicacy in the dataset

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# **Observations**
# - There is no any duplicate values in the dataset

# %% [markdown]
# # Checking the Invalid Values in the Data set

# %%
for i in Num.columns:
    for j in Num[i]:
        if j<0:
            print('Invalid Value')

# %% [markdown]
# **Observations**
# - I had run the code but there is no any output, it means there is no any invalid values in the data set.
# - Because Year of Bought, Sales Price and KM Driven must not be in negative values.

# %% [markdown]
# # Checking the Inconsistency in the data set

# %%
for i in Cat.columns:
        print(i,'       ',Cat[i].unique(),'has',Cat[i].nunique(),'values',end='\n\n')
# Out:
# Fuel Type         ['Petrol' 'Diesel' 'Petrol + CNG'] has 3 values
#
# City         ['Ghaziabad' 'Gurgaon' 'New Delhi' 'Noida' 'Faridabad' 'Rohtak' 'Panipat'
#  'Sonipat'] has 8 values
#
# Body Type         ['Hatchback' 'Sedan' 'SUV' 'Luxury Sedan' nan 'Luxury SUV'] has 5 values
#
# Transmission         ['Manual' 'Automatic' nan] has 2 values
#
# Registration City         ['Agra' 'Gurgaon' 'Delhi' 'Rewari' 'Rohtak' 'New Delhi' 'Moradabad'
#  'Noida' 'Ghaziabad' 'Sonipat' 'Faridabad' 'Delhi West' 'Ambala'
#  'Goutam  Budd  Nagar' 'Hissar' 'Jhajjar' 'Derabassi' 'Charkhi Dadri'
#  'Lucknow' 'Bahadurgarh' 'Jagadhri' 'Narwana' 'Ambala City' 'Meerut'
#  'Kalka' 'Mathura' 'Karnal' 'Barda' 'Sirsa' 'Fatehabad' 'Palwal'
#  'Bulandshahr' 'Mirzapur' 'Sohana' 'Hapur' 'Pratapgarh' 'Bareilly'
#  'Panchkula'] has 38 values
#
# State         ['Uttar Pradesh' 'Haryana' 'Delhi' 'Punjab'] has 4 values
#
# Company         ['DATSUN' 'HYUNDAI' 'KIA' 'HONDA' 'VOLKSWAGEN' 'MERCEDES BENZ' 'RENAULT'
# ...

# %% [markdown]
# **Observations**
# - From my domain knowledge there is no any inconsistency in the dataset.
# - All the values in the categorical columns have unique values.
# - As per the categorical column all values are spelled correctly.

# %% [markdown]
# # Filling the missing values as per our Domain Knowledge of the Dataset

# %%
df['Body Type'].mode()
# Out:
# 0    Hatchback
# Name: Body Type, dtype: object

# %%
df['Transmission'].mode()
# Out:
# 0    Manual
# Name: Transmission, dtype: object

# %%
pd.set_option('display.max_rows',None)

# %% [markdown]
# **Observations**
# - This Upper code help us to review all the rows and columns in our dataset, which is very beneficial for data analysis purpose.

# %%
df[['Body Type','Transmission']]
# Out:
#           Body Type Transmission
# Index
# 0         Hatchback       Manual
# 1             Sedan       Manual
# 2               SUV    Automatic
# 3               SUV       Manual
# 4               SUV    Automatic
# 5             Sedan       Manual
# 6               SUV       Manual
# 7         Hatchback       Manual
# 8         Hatchback       Manual
# 9         Hatchback       Manual
# 10     Luxury Sedan    Automatic
# 11              NaN          NaN
# 12              SUV       Manual
# 13            Sedan       Manual
# 14              NaN          NaN
# 15              SUV       Manual
# 16        Hatchback       Manual
# 17        Hatchback    Automatic
# 18        Hatchback       Manual
# 19     Luxury Sedan    Automatic
# 20       Luxury SUV       Manual
# 21        Hatchback       Manual
# 22            Sedan       Manual
# 23        Hatchback       Manual
# 24        Hatchback       Manual
# 25            Sedan    Automatic
# 26              NaN          NaN
# ...

# %% [markdown]
# **Observations**
# - As i mentioned above that there are only near about 3.7 % of missing values are there in both of these 2 columns Body Type and   Transmission
# - I checked thoroughly that both the columns have same number of Nan values at the same index number so, we can fill it   with the mode.
# - As there is very less % of missing values in the data, so we can fill it with the mode and also it does not voilate our dataset while visualisation.

# %%
df['Body Type']=df['Body Type'].fillna(df['Body Type'].mode()[0])

# %%
df['Transmission']=df['Transmission'].fillna(df['Transmission'].mode()[0])

# %%
df[['Body Type','Transmission']].isnull().sum()
# Out:
# Body Type       0
# Transmission    0
# dtype: int64

# %% [markdown]
# ## Checking the missing values again in the dataset

# %%
df.isnull().sum().to_frame().T
# Out:
#    Year of bought  Fuel Type  KM Driven  Sales Price  City  Body Type  \
# 0               0          0          0            0     0          0
#
#    Transmission  Registration City  State  Company  Model
# 0             0                  0      0        0      0

# %% [markdown]
# **Observations**
# - All the missing values has to be filled in the data set.
# - now we can move further part of our analysis.

# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:5px;
#            background-color:pink;
#            font-size:200%;
#            font-family:Serif;
#            letter-spacing:0.5px">
#
# <p style="padding: 10px;
#           color:black;
#           font-size:120%;
#           text-align:center;">
# Preview of the Data
# </p>
# </div>

# %%
df.sample(5)
# Out:
#        Year of bought Fuel Type  KM Driven  Sales Price       City  \
# Index
# 576              2014    Diesel      70100       989999  New Delhi
# 260              2014    Diesel      91772      1346499  Faridabad
# 221              2019    Diesel      23602       898599  New Delhi
# 384              2015    Diesel     122884       455899  New Delhi
# 403              2017    Diesel      69262       649099     Rohtak
#
#           Body Type Transmission Registration City    State Company  \
# Index
# 576             SUV       Manual         New Delhi    Delhi  TOYOTA
# 260    Luxury Sedan    Automatic           Gurgaon  Haryana    AUDI
# 221             SUV       Manual         New Delhi    Delhi  MARUTI
# 384           Sedan       Manual         New Delhi    Delhi  MARUTI
# 403             SUV       Manual             Delhi    Delhi  MARUTI
#
#                Model
# Index
# 576           INNOVA
# 260               A3
# 221    VITARA BREZZA
# 384             CIAZ
# ...

# %% [markdown]
# **NOTE**
# - We do not use Feature Engineering Column Extraction from date column in the data due to there is no any proper date column in our Data set.
# - We do not use Astype function in the project because all the columns are in appropriate data types.

# %% [markdown]
# # Descriptive Analysis of the Data

# %%
df.describe().T
# Out:
#                 count           mean            std       min        25%  \
# Year of bought  592.0    2017.246622       2.652456    2009.0    2015.00
# KM Driven       592.0   45596.574324   29485.332086      78.0   22631.75
# Sales Price     592.0  701106.939189  377097.344905  171499.0  426124.00
#
#                      50%       75%        max
# Year of bought    2017.0    2019.0     2022.0
# KM Driven        40238.5   68357.0   161137.0
# Sales Price     602299.0  826724.0  2148399.0

# %%
df.head(3)
# Out:
#        Year of bought Fuel Type  KM Driven  Sales Price       City  Body Type  \
# Index
# 0                2018    Petrol      22664       242999  Ghaziabad  Hatchback
# 1                2019    Petrol      81902       981699    Gurgaon      Sedan
# 2                2020    Petrol       8241      1895199  New Delhi        SUV
#
#       Transmission Registration City          State  Company    Model
# Index
# 0           Manual              Agra  Uttar Pradesh   DATSUN  REDI GO
# 1           Manual           Gurgaon        Haryana  HYUNDAI    VERNA
# 2        Automatic             Delhi          Delhi      KIA   SELTOS

# %% [markdown]
# ### Average Year of bought

# %%
df['Year of bought'].mean()
# Out:
# 2017.2466216216217

# %% [markdown]
# ### How many deals done in the Average year of bought

# %%
df[df['Year of bought']==2017]['Sales Price'].count()
# Out:
# 90

# %% [markdown]
# **Observations**
# - There is 90 deals has to be done in the year of 2017
# - Sales Price of the Car is considered as the Car Sales deal
# - we can count sales price row wise as fair deal of the car sales

# %% [markdown]
# ### Average KM Driven by the owner of the Car

# %%
df['KM Driven'].mean()
# Out:
# 45596.57432432433

# %% [markdown]
# ### Find the Average KM driven where Fuel type is Petrol, Transmission is Manual and body type is Hatchback

# %%
df.groupby(['Fuel Type','Transmission','Body Type'])['KM Driven'].mean().to_frame()
# Out:
#                                             KM Driven
# Fuel Type    Transmission Body Type
# Diesel       Automatic    Luxury SUV     70908.833333
#                           Luxury Sedan   61926.200000
#                           SUV            50563.500000
#                           Sedan          45563.000000
#              Manual       Hatchback      69837.611111
#                           Luxury SUV     75644.875000
#                           Luxury Sedan   95101.500000
#                           SUV            57669.076923
#                           Sedan          74794.260870
# Petrol       Automatic    Hatchback      35761.392857
#                           Luxury SUV     31087.500000
#                           Luxury Sedan   58395.000000
#                           SUV            28911.058824
#                           Sedan          28731.846154
#              Manual       Hatchback      31310.399038
#                           Luxury SUV     42490.000000
# ...

# %% [markdown]
# **Observations**
# - The Average KM driven where Fuel type is Petrol, Transmission is Manual and body type is Hatchback is 31310

# %% [markdown]
# ### Average Sales Price of the car year on year basis

# %%
df.groupby('Year of bought')['Sales Price'].mean().to_frame()
# Out:
#                   Sales Price
# Year of bought
# 2009            228799.000000
# 2010            294874.000000
# 2011            308232.333333
# 2012            353465.666667
# 2013            581926.027027
# 2014            566999.000000
# 2015            555067.085106
# 2016            627416.543860
# 2017            618766.777778
# 2018            642264.384615
# 2019            863976.906977
# 2020            909656.352941
# 2021            937983.615385
# 2022            823989.000000

# %% [markdown]
# ### Average sales of the car year on year basis whose KM Driven is more than 1,00,000

# %%
Avg_sales_1=df[df['KM Driven']>100000]
Avg_sales_1
# Out:
#        Year of bought     Fuel Type  KM Driven  Sales Price       City  \
# Index
# 164              2013        Diesel     121564       348599    Gurgaon
# 275              2014        Diesel     159515       383499  New Delhi
# 284              2013        Diesel     119092       297199    Gurgaon
# 290              2014        Petrol     117068       662499      Noida
# 309              2013        Diesel     117736      1044599  New Delhi
# 337              2013        Diesel     119546       419799  New Delhi
# 355              2015        Diesel     121686       462799  New Delhi
# 361              2014        Diesel     127926       643399    Gurgaon
# 380              2016        Diesel     106627       397899     Rohtak
# 384              2015        Diesel     122884       455899  New Delhi
# 405              2017        Diesel     113206       542999  New Delhi
# 418              2014        Diesel     102991       339799  New Delhi
# ...

# %%
Avg_sales_1.groupby('Year of bought')['Sales Price'].mean().to_frame()
# Out:
#                   Sales Price
# Year of bought
# 2010            190799.000000
# 2013            444449.000000
# 2014            472265.666667
# 2015            459349.000000
# 2016            489149.000000
# 2017            657749.000000

# %% [markdown]
# ### Maximum & Minimum Sales in which year

# %%
df.groupby('Year of bought')['Sales Price'].agg([max,min])
# Out:
#                     max     min
# Year of bought
# 2009             270199  204699
# 2010             402699  190799
# 2011             442399  187299
# 2012             412099  250499
# 2013            1549999  293399
# 2014            2029199  257999
# 2015            1966499  256299
# 2016            1815699  171499
# 2017            1408199  331199
# 2018            1318099  242999
# 2019            2148399  315799
# 2020            1928399  378699
# 2021            2111499  379299
# 2022             993499  567399

# %% [markdown]
# **Observations**
# - Maximum sales is to be done in 2019 year -2148399
# - Minimum sales is to be done in 2016 year -171499

# %% [markdown]
# ### Minimum & Minimum KM Driven in which Year by which Company

# %%
df.groupby(['Year of bought','Company'])['KM Driven'].agg([min,max])
# Out:
#                                  min     max
# Year of bought Company
# 2009           HONDA           90814   90814
#                HYUNDAI         21723   44327
# 2010           HONDA           39565   55387
#                MARUTI          48998  121180
# 2011           HONDA           52035   80818
#                HYUNDAI         16869   16869
#                MARUTI          38042   78068
#                TOYOTA          68160   68160
# 2012           HONDA           50540   74390
#                HYUNDAI         87972   87972
#                MARUTI          13159   63076
# 2013           AUDI            30686   89740
#                BMW             71180   83330
#                FORD            33832  114858
#                HONDA           31353   48160
#                HYUNDAI         10558  121564
#                JAGUAR          28909   28909
#                MAHINDRA        72062   72062
#                MARUTI          38725  161137
# ...

# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:5px;
#            background-color:pink;
#            font-size:200%;
#            font-family:Serif;
#            letter-spacing:0.5px">
#
# <p style="padding: 10px;
#           color:black;
#           font-size:120%;
#           text-align:center;">
# INSIGHTS OF THE DATA SET
# </p>
# </div>

# %% [markdown]
# ## Bivariate Analysis

# %%
df.head(3)
# Out:
#        Year of bought Fuel Type  KM Driven  Sales Price       City  Body Type  \
# Index
# 0                2018    Petrol      22664       242999  Ghaziabad  Hatchback
# 1                2019    Petrol      81902       981699    Gurgaon      Sedan
# 2                2020    Petrol       8241      1895199  New Delhi        SUV
#
#       Transmission Registration City          State  Company    Model
# Index
# 0           Manual              Agra  Uttar Pradesh   DATSUN  REDI GO
# 1           Manual           Gurgaon        Haryana  HYUNDAI    VERNA
# 2        Automatic             Delhi          Delhi      KIA   SELTOS

# %% [markdown]
# # Which year has the highest total sales

# %%
df1=df.groupby('Year of bought')['Sales Price'].sum().to_frame()
df1
# Out:
#                 Sales Price
# Year of bought
# 2009                 915196
# 2010                1179496
# 2011                1849394
# 2012                2120794
# 2013               21531263
# 2014               26648953
# 2015               26088153
# 2016               35762743
# 2017               55689010
# 2018               50096622
# 2019               74302014
# 2020               61856632
# 2021               48775148
# 2022                8239890

# %%
plt.figure(figsize=(9,5),facecolor='ORANGE')
plt.plot(df1.index,df1.values,color='red',linewidth=2)
plt.xticks(list(range(2009,2022)),rotation=90)
plt.grid(color="green",linestyle="dashed")
plt.title('Sales Trend over the Years',fontsize=15,fontweight='bold')
plt.xlabel('Years',fontweight='bold',fontsize=12,labelpad=15)
plt.ylabel('Sales Price',fontweight='bold',fontsize=12,labelpad=15)
plt.show()

# %% [markdown]
# **Observations**
# - Sales peak in the Year of 2019 and sudden dip after that due to the reason of COVID in INDIA.
# - Peak Sales Year is 2019 and Slowest sales year is 2009 as shown in the above trend
# - 2019 has the highest total sales of car bought year followed by 2020 and 2017.
# - 74302014 is the highest total sales of car in 2019 year then 61856632 is the second highest total sales of car in 2020.
# - 2018 and 2021 car sales are almost same as we saw in the above trend

# %% [markdown]
# # Which State/Region has the highest total sales

# %%
df2=df.groupby('State')['Sales Price'].sum().sort_values(ascending=False)
df2
# Out:
# State
# Delhi            212281079
# Haryana          133010309
# Uttar Pradesh     69273221
# Punjab              490699
# Name: Sales Price, dtype: int64

# %%
plt.figure(figsize=(9,5),facecolor='ORANGE')
plt.bar(df2.index,df2.values,color='Grey',edgecolor='black')
plt.title('Car Sales State Wise',fontsize=15,fontweight='bold')
plt.xlabel('State',fontweight='bold',fontsize=12,labelpad=15)
plt.ylabel('Sales Price',fontweight='bold',fontsize=12,labelpad=15)
plt.show()

# %% [markdown]
# **Obervations**
# - Delhi is leading in the total sales of the car state wise
# - Haryana is holding the 2nd position in the same list
# - we can assume that Delhi's People spent alot of money on vehicle to look good as compared to other states
# - We can also assume that delhi's people are getting paid high salaries as compared to other states
# - These reasons may attract the sales of the car in Delhi.

# %% [markdown]
# # Which city has the highest total sales

# %%
df['City'].unique()
# Out:
# array(['Ghaziabad', 'Gurgaon', 'New Delhi', 'Noida', 'Faridabad',
#        'Rohtak', 'Panipat', 'Sonipat'], dtype=object)

# %%
df.groupby(['City'])['Sales Price'].sum().sort_values(ascending=False)
# Out:
# City
# New Delhi    189370439
# Gurgaon      109926141
# Noida         49008634
# Faridabad     27815056
# Ghaziabad     18466577
# Rohtak        12052778
# Panipat        7895284
# Sonipat         520399
# Name: Sales Price, dtype: int64

# %%
plt.figure(figsize=(10,5),facecolor='ORANGE')
plt.bar(df.groupby(['City'])['Sales Price'].sum().sort_values(ascending=False).index,df.groupby(['City'])['Sales Price'].sum().sort_values(ascending=False).values,edgecolor='black')
plt.xlabel('City',fontweight='bold',fontsize=15)
plt.ylabel('Sales Price',fontweight='bold',fontsize=15)
plt.xticks(rotation=90)
plt.title('City Wise Total sales',fontweight='bold',fontsize=20)
plt.show()

# %% [markdown]
# **Observations**
# - New Delhi is the leading city in terms of sales of the Car, due to better infrastructure in new delhi for driving the car, good facilities are there, timely services provided by the workshop in delhi
# - Gurgaon is the second highest city whose sales is more than other cities except New delhi

# %%
cities=df['City'].values
cities
# Out:
# array(['Ghaziabad', 'Gurgaon', 'New Delhi', 'Gurgaon', 'New Delhi',
#        'Gurgaon', 'Gurgaon', 'Gurgaon', 'New Delhi', 'New Delhi',
#        'New Delhi', 'Noida', 'Gurgaon', 'New Delhi', 'New Delhi',
#        'New Delhi', 'New Delhi', 'Gurgaon', 'Faridabad', 'Ghaziabad',
#        'New Delhi', 'New Delhi', 'New Delhi', 'New Delhi', 'Ghaziabad',
#        'Noida', 'New Delhi', 'Gurgaon', 'Gurgaon', 'Faridabad',
#        'New Delhi', 'Gurgaon', 'New Delhi', 'New Delhi', 'New Delhi',
#        'Gurgaon', 'New Delhi', 'New Delhi', 'Gurgaon', 'New Delhi',
#        'New Delhi', 'New Delhi', 'New Delhi', 'Noida', 'Noida',
#        'New Delhi', 'Noida', 'Gurgaon', 'Rohtak', 'Rohtak', 'New Delhi',
#        'New Delhi', 'Noida', 'New Delhi', 'New Delhi', 'New Delhi',
#        'Ghaziabad', 'Noida', 'New Delhi', 'Panipat', 'New Delhi',
#        'Faridabad', 'New Delhi', 'Gurgaon', 'New Delhi', 'New Delhi',
#        'Gurgaon', 'Gurgaon', 'Gurgaon', 'Faridabad', 'New Delhi',
# ...

# %%
city=' '.join(cities)
city
# Out:
# 'Ghaziabad Gurgaon New Delhi Gurgaon New Delhi Gurgaon Gurgaon Gurgaon New Delhi New Delhi New Delhi Noida Gurgaon New Delhi New Delhi New Delhi New Delhi Gurgaon Faridabad Ghaziabad New Delhi New Delhi New Delhi New Delhi Ghaziabad Noida New Delhi Gurgaon Gurgaon Faridabad New Delhi Gurgaon New Delhi New Delhi New Delhi Gurgaon New Delhi New Delhi Gurgaon New Delhi New Delhi New Delhi New Delhi Noida Noida New Delhi Noida Gurgaon Rohtak Rohtak New Delhi New Delhi Noida New Delhi New Delhi New Delhi Ghaziabad Noida New Delhi Panipat New Delhi Faridabad New Delhi Gurgaon New Delhi New Delhi Gurgaon Gurgaon Gurgaon Faridabad New Delhi Gurgaon Gurgaon New Delhi Gurgaon New Delhi New Delhi Faridabad Noida New Delhi Gurgaon New Delhi Gurgaon Gurgaon New Delhi New Delhi Faridabad New Delhi New Delhi Gurgaon New Delhi Noida New Delhi New Delhi New Delhi Gurgaon New Delhi Gurgaon New Delhi New Delhi New Delhi New Delhi New Delhi Noida Gurgaon New Delhi Gurgaon New Delhi New Delhi Noida New D
# ...

# %%
#pip install wordcloud

# %%
from wordcloud import WordCloud

# %%
wordcloud = WordCloud(width=800, height=800, background_color='black').generate(city)
plt.figure(figsize=(14,8), facecolor=None)
plt.imshow(wordcloud)
plt.tight_layout(pad=0)
plt.show()

# %% [markdown]
# **Observations**
# - We have to make city in a single string from a list to form a Word Cloud visualization,so i used join function to do the same.
# - We clearly see that New Delhi has the highest sales followed by Gurgoan, because it represent the word frequency that give greater prominence to words   that appear more frequently in a source text.

# %% [markdown]
# # Top 5 City has the highest total sales

# %%
df3=df.groupby('City')['Sales Price'].sum().sort_values(ascending=False).head()
df3
# Out:
# City
# New Delhi    189370439
# Gurgaon      109926141
# Noida         49008634
# Faridabad     27815056
# Ghaziabad     18466577
# Name: Sales Price, dtype: int64

# %%
plt.figure(figsize=(15,6))
plt.pie(df3.values,labels=df3.index,autopct='%.1f%%',shadow=True,explode=[0,0,0,1,1])
plt.show()

# %% [markdown]
# **Observations**
# - Delhi has the highest total sales of car as compared to other cities followed by new delhi and gurgaon.
# - It means in northen india delhi's people are showing more interest for buying the car as compared to other state's people.

# %%
df.head()
# Out:
#        Year of bought Fuel Type  KM Driven  Sales Price       City  Body Type  \
# Index
# 0                2018    Petrol      22664       242999  Ghaziabad  Hatchback
# 1                2019    Petrol      81902       981699    Gurgaon      Sedan
# 2                2020    Petrol       8241      1895199  New Delhi        SUV
# 3                2020    Petrol      32799      1375499    Gurgaon        SUV
# 4                2019    Petrol      37357      1666099  New Delhi        SUV
#
#       Transmission Registration City          State  Company    Model
# Index
# 0           Manual              Agra  Uttar Pradesh   DATSUN  REDI GO
# 1           Manual           Gurgaon        Haryana  HYUNDAI    VERNA
# 2        Automatic             Delhi          Delhi      KIA   SELTOS
# 3           Manual            Rewari        Haryana      KIA   SELTOS
# 4        Automatic            Rohtak        Haryana      KIA   SELTOS

# %% [markdown]
# # Top 5 Company wise sales of the car

# %%
df4=df.groupby('Company')['Sales Price'].sum().sort_values(ascending=False).head()
df4
# Out:
# Company
# MARUTI      139589143
# HYUNDAI      65402704
# HONDA        38637846
# MAHINDRA     27120974
# FORD         24789363
# Name: Sales Price, dtype: int64

# %%
plt.figure(figsize=(10,5),facecolor='ORANGE')
plt.bar(df4.index,df4.values,edgecolor='black')
plt.title('Top 5 Company Wise Car Sales',fontsize=15,fontweight='bold')
plt.xlabel('Company',fontweight='bold',fontsize=12,labelpad=15)
plt.ylabel('Sales Price',fontweight='bold',fontsize=12,labelpad=15)
plt.show()

# %% [markdown]
# **Observations**
# - Maruti is the top most selling car company in the data set
# - Reason- Maruti company provide better mileage and body parts while servicing the cars

# %% [markdown]
# # Company wise Sales on Year Basis

# %%
df7=df.groupby(['Year of bought','Company'])['Sales Price'].sum().to_frame().sort_values(by=['Year of bought','Sales Price'],ascending=False)
df8=df7.reset_index()
df8
# Out:
#      Year of bought        Company  Sales Price
# 0              2022           TATA      2465597
# 1              2022         MARUTI      2095797
# 2              2022        HYUNDAI       993499
# 3              2022          HONDA       945599
# 4              2022       MAHINDRA       900299
# 5              2022         NISSAN       839099
# 6              2021         MARUTI     11211083
# 7              2021           TATA      9597591
# 8              2021       MAHINDRA      8321394
# 9              2021        HYUNDAI      3987396
# 10             2021         TOYOTA      3194397
# 11             2021        RENAULT      2196797
# 12             2021           FORD      2179798
# 13             2021             MG      1837899
# 14             2021         NISSAN      1800698
# 15             2021            KIA      1389299
# 16             2021          SKODA      1172199
# 17             2021          HONDA       965599
# 18             2021         DATSUN       920998
# ...

# %%
plt.figure(figsize=(12,5),facecolor='ORANGE')

plt.subplot(1,2,1)
plt.bar(df8['Company'],df8['Sales Price'],edgecolor='black')
plt.title('Car Sales Company Wise',fontsize=15,fontweight='bold')
plt.xlabel('Company',fontweight='bold',fontsize=12,labelpad=15)
plt.ylabel('Sales Price',fontweight='bold',fontsize=12,labelpad=15)
plt.xticks(rotation=90)

plt.subplot(1,2,2)
plt.plot(df8['Year of bought'],df8['Sales Price'],color='red')
plt.title('Sales Trend over the Years',fontsize=15,fontweight='bold')
plt.xlabel('Years',fontweight='bold',fontsize=12,labelpad=15)
plt.grid(color="green",linestyle="dashed")
plt.xticks(list(range(2009,2023)),rotation=90);

plt.show()

# %% [markdown]
# **Obervations**
# - We clearly see that Maruti is the top selling car company as compared to other companies.
# - Second most selling car company is hyundai and third most selling car company is MG and Tata
# - Trend of the company wise car sales shows that there is many ups and down in the markets
# - Highest Car sales company wise year is to be 2017 and second highest year is to be 2019

# %% [markdown]
# # Best Selling Body Type of the Car

# %%
df.groupby('Body Type')['Sales Price'].sum().sort_values(ascending=False)
# Out:
# Body Type
# SUV             158217227
# Hatchback       152660200
# Sedan            59175816
# Luxury SUV       24385383
# Luxury Sedan     20616682
# Name: Sales Price, dtype: int64

# %%
plt.pie(df.groupby('Body Type')['Sales Price'].sum().sort_values(ascending=False).values,labels=df.groupby('Body Type')['Sales Price'].sum().sort_values(ascending=False).index,autopct='%.1f%%',shadow=True);
circle = plt.Circle( (0,0), 0.4, color='white')
p=plt.gcf()
p.gca().add_artist(circle);

# %% [markdown]
# **Observations**
# - SUV body type is leading in the total sales values.
# - Hatchback body type tooks second place in leading the total sales value.

# %% [markdown]
# # Which body type of the car is more demanded

# %%
df['Body Type'].value_counts()
# Out:
# Body Type
# Hatchback       300
# SUV             173
# Sedan            84
# Luxury Sedan     18
# Luxury SUV       17
# Name: count, dtype: int64

# %%
plt.pie(df['Body Type'].value_counts().values,labels=df['Body Type'].value_counts().index,autopct='%.1f%%',explode=[0,0,0,1,1],shadow=True);

# %% [markdown]
# **Observations**
# - Most selling Body type of the Car is Hatchback
# - but the Total sales value of SUV is higher than the Hatchback
# - Most demanding body type of the car is Hatchback
# - Hatchback body type captures the 50% of the market shares in the data followed by SUV body type

# %%
df.head(5)
# Out:
#        Year of bought Fuel Type  KM Driven  Sales Price       City  Body Type  \
# Index
# 0                2018    Petrol      22664       242999  Ghaziabad  Hatchback
# 1                2019    Petrol      81902       981699    Gurgaon      Sedan
# 2                2020    Petrol       8241      1895199  New Delhi        SUV
# 3                2020    Petrol      32799      1375499    Gurgaon        SUV
# 4                2019    Petrol      37357      1666099  New Delhi        SUV
#
#       Transmission Registration City          State  Company    Model
# Index
# 0           Manual              Agra  Uttar Pradesh   DATSUN  REDI GO
# 1           Manual           Gurgaon        Haryana  HYUNDAI    VERNA
# 2        Automatic             Delhi          Delhi      KIA   SELTOS
# 3           Manual            Rewari        Haryana      KIA   SELTOS
# 4        Automatic            Rohtak        Haryana      KIA   SELTOS

# %% [markdown]
# # Which Transmission is more demanding

# %%
df['Transmission'].value_counts()
# Out:
# Transmission
# Manual       503
# Automatic     89
# Name: count, dtype: int64

# %%
plt.figure(figsize=(8,5),facecolor='ORANGE')
plt.bar(df['Transmission'].value_counts().index,df['Transmission'].value_counts().values,color=['Red','Orange'],edgecolor='black',label=['Manual','AMT'])
plt.xlabel('Transmission',fontweight='bold')
plt.ylabel('Counts',fontweight='bold')
plt.legend();

# %% [markdown]
# **Observations**
# - As we show above that Manual transmission is more demanding car as compared to AMT transmission.
# - Manual transmission car approximately 6 times more bought car than AMT transmission car

# %% [markdown]
# # Best Selling Car model

# %%
df.groupby('Model')['Sales Price'].sum().sort_values(ascending=False).head(10)
# Out:
# Model
# VITARA BREZZA    29054459
# BALENO           27076555
# ECOSPORT         24212364
# CRETA            23901279
# SWIFT            19610455
# CITY             15221178
# HECTOR           13598892
# GRAND I10        12190374
# CIAZ             12066983
# SELTOS           10061893
# Name: Sales Price, dtype: int64

# %%
plt.figure(figsize=(10,6),facecolor='ORANGE')
plt.bar(df.groupby('Model')['Sales Price'].sum().sort_values(ascending=False).head(10).index,df.groupby('Model')['Sales Price'].sum().sort_values(ascending=False).head(10).values,edgecolor='black');
plt.xticks(rotation=90)
plt.xlabel('Model',fontweight='bold')
plt.ylabel('Sales Price',fontweight='bold')
plt.show()

# %%
df[df['Model']=='VITARA BREZZA'].head(2)
# Out:
#        Year of bought Fuel Type  KM Driven  Sales Price       City Body Type  \
# Index
# 62               2017    Diesel      28496       657799  New Delhi       SUV
# 110              2017    Diesel      38072       797999  New Delhi       SUV
#
#       Transmission Registration City  State Company          Model
# Index
# 62          Manual         New Delhi  Delhi  MARUTI  VITARA BREZZA
# 110         Manual         New Delhi  Delhi  MARUTI  VITARA BREZZA

# %% [markdown]
# **Observations**
# - Vitara Brezza is the best selling car model in the data set
# - Brezza belongs to the Maruti company as we shown above by filtering the data
# - Top 8 most demanding car model we have seen above in the bar charts
# - Vitara Brezza is the most demanding model in the data set
# - Reason- Maruti company may provide better satisfaction to their potential customers, Brezza may provide better mileage and       services as compared to companies.

# %% [markdown]
# # Which Car model has more in demand

# %%
df['Model'].value_counts().head(8)
# Out:
# Model
# BALENO           45
# SWIFT            45
# VITARA BREZZA    41
# ECOSPORT         36
# GRAND I10        26
# CITY             22
# CRETA            21
# CIAZ             17
# Name: count, dtype: int64

# %%
plt.pie(df['Model'].value_counts().head(8).values,labels=df['Model'].value_counts().head(8).index,autopct="%.1f%%");

# %% [markdown]
# **Observations**
# - We clearly see that Swift and Baleno they both are equally most demanding car model in the data set.
# - It may provide more comfort and satisfaction to their customer and better mileage attracts new buyers in the market.

# %%
df.head(3)
# Out:
#        Year of bought Fuel Type  KM Driven  Sales Price       City  Body Type  \
# Index
# 0                2018    Petrol      22664       242999  Ghaziabad  Hatchback
# 1                2019    Petrol      81902       981699    Gurgaon      Sedan
# 2                2020    Petrol       8241      1895199  New Delhi        SUV
#
#       Transmission Registration City          State  Company    Model
# Index
# 0           Manual              Agra  Uttar Pradesh   DATSUN  REDI GO
# 1           Manual           Gurgaon        Haryana  HYUNDAI    VERNA
# 2        Automatic             Delhi          Delhi      KIA   SELTOS

# %% [markdown]
# ## Which Fuel Type has more in demand

# %%
df['Fuel Type'].value_counts()
# Out:
# Fuel Type
# Petrol          348
# Diesel          231
# Petrol + CNG     13
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10,6),facecolor='ORANGE')
plt.bar(df['Fuel Type'].value_counts().index,df['Fuel Type'].value_counts().values,edgecolor='black')
plt.xticks(rotation=90)
plt.xlabel('Fuel Type',fontweight='bold')
plt.ylabel('Counts',fontweight='bold')
plt.show()

# %% [markdown]
# **Observations**
# - We see that Petrol Fuel type car has more in demand in the data set
# - The Reason that i assume cost of Petrol Fuel type car is less than the other Fuel type cars
# - Another reason that i considered, the petrol fuel type car validity is more than the other fuel type car validity.

# %%
df[df['City']==df['Registration City']]
# Out:
#        Year of bought     Fuel Type  KM Driven  Sales Price       City  \
# Index
# 1                2019        Petrol      81902       981699    Gurgaon
# 5                2014        Petrol      61168       659699    Gurgaon
# 9                2011        Petrol      16869       187299  New Delhi
# 15               2020        Petrol      32873      1226699  New Delhi
# 24               2020        Petrol       6470       608399  Ghaziabad
# 27               2015        Petrol      48952       256299    Gurgaon
# 28               2019        Diesel      46860      1946899    Gurgaon
# 29               2021        Petrol       3168       693899  Faridabad
# 32               2019        Petrol      23327      2037899  New Delhi
# 33               2012        Petrol      74390       250499  New Delhi
# 38               2020        Petrol      10572       452199    Gurgaon
# 39               2020        Petrol      13265       565199  New Delhi
# ...

# %%
df[df['City']!=df['Registration City']]
# Out:
#        Year of bought     Fuel Type  KM Driven  Sales Price       City  \
# Index
# 0                2018        Petrol      22664       242999  Ghaziabad
# 2                2020        Petrol       8241      1895199  New Delhi
# 3                2020        Petrol      32799      1375499    Gurgaon
# 4                2019        Petrol      37357      1666099  New Delhi
# 6                2019        Diesel      25067      1307499    Gurgaon
# 7                2016        Petrol      30738       171499    Gurgaon
# 8                2016        Petrol      46878       439199  New Delhi
# 10               2014        Petrol      37531      2029199  New Delhi
# 11               2021        Petrol      14474       823199      Noida
# 12               2017        Petrol      17511       783499    Gurgaon
# 13               2014        Petrol      20567       605299  New Delhi
# 14               2021        Petrol       7416       720199  New Delhi
# ...

# %% [markdown]
# **Obervations**
# - We see that in above scenario Store city and registration city is same, it means people bought their car from the same store city where they located with full satisfaction.
# - But the another scenario is Vice versa.
# - Store city and Registration City is not the same, in this case i assume that people are not satisfied with the car dealers,it might be the store city does not fulfill the requirements of customers
# - That's the reason people traveled far away for buying the cars

# %% [markdown]
# ## Conclusion

# %% [markdown]
# - SUVs and Hatchback are the Most Popular car types, accounting for over 75% of sales
# - The Majority of Car buyers from Delhi as compared to other cities
# - The Average Sales price of the Car is around rs 700000 with a range of 171499 to 2148399
# - The best selling model are from Maruti,Ford, Hyundai with the Vitara Brezza being the top selling model
# - Sales peak in the Year of 2019 and sudden dip after that due to the reason of COVID in india

# %% [markdown]
# # SQL Queries

# %% [markdown]
# Write SQL queries to extract specific information from the dataset. For example,
# you might write a query to find the top-performing products or to identify trends
# over time.
# Document the SQL queries used and explain their purpose.

# %%
df.head(3)
# Out:
#        Year of bought Fuel Type  KM Driven  Sales Price       City  Body Type  \
# Index
# 0                2018    Petrol      22664       242999  Ghaziabad  Hatchback
# 1                2019    Petrol      81902       981699    Gurgaon      Sedan
# 2                2020    Petrol       8241      1895199  New Delhi        SUV
#
#       Transmission Registration City          State  Company    Model
# Index
# 0           Manual              Agra  Uttar Pradesh   DATSUN  REDI GO
# 1           Manual           Gurgaon        Haryana  HYUNDAI    VERNA
# 2        Automatic             Delhi          Delhi      KIA   SELTOS

# %% [markdown]
# ## Find the Top performing models company wise in the dataset

# %% [markdown]
# selecy * from (select *,
# dense_rank() over(partition by Company order by Sales Price desc) as Top_sales
# from df ) as tt where top_sales<2;
#
#
# **Purpose**
# - Finding the top performing car models on the basis of company
# - I use dense rank function for ranking the top perfroming model
# - Dense rank does not leave gaps in the ranking
# - I assume that the Data Frame of Pandas which denoted by df is the Table in SQL

# %% [markdown]
# ## Which body type of the car has highest total sales

# %% [markdown]
# select Body Type,sum(Sales Price) as Total_Sales from df group by Body Type order by Total_sales desc limit 1;
#
# **Purpose**
# - I assume that the Data Frame of Pandas which denoted by df is the Table in SQL
# - I use group by clause, order by clause and aggregate function for finding the highest total sales of body type of the car
# - it result me the highest sales of body type of the car

# %% [markdown]
# ## Find the total sales of each store city

# %% [markdown]
# select City,sum(Sales Price) as Total_sales from df group by City order by Total_sales desc;
#
# **Purpose**
# - This query gives me the total sales of the car in each city in descending order
# - For this query i use group by clause for grouping the city and order by clause for arranging them in an order

# %% [markdown]
# ## Find which city has the most Registrations of the car

# %% [markdown]
# select Registration City,count(Registration City) as Count from df group by Registration City limit 1;
#
# **Purpose**
# - This query solved me to find the City who has done the maximum number of car registrations
# - I use group by clause for grouping the distinct city to find the maximum number of car registration city

# %% [markdown]
# ## Top 2 year has the highest total sales

# %% [markdown]
# select Year of bought,sum(Sales Price) as Total_sales from df group by Year of bought order by Total_sales desc limit 2;
#
# **Purpose**
# - This query helps me to find the top 2 year has the highest car sales
# - i use group by clause for grouping the year, to find top 2 i use limit clause

# %% [markdown]
# ## Bottom 2 year has the lowest sales

# %% [markdown]
# select Year of bought,sum(Sales Price) as Total_sales from df group by Year of bought order by Total_sales limit 2;
#
# **Purpose**
# - This query helps me to find the bottom 2 year has the lowest car sales
# - i use group by clause for grouping the year, to find bottom 2 i use limit clause
